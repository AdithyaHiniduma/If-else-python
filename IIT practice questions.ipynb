# %%
name='Adithya'
print(name)
# Out:
# Adithya

# %%
x=10
y=20
print(x+y)
# Out:
# 30

# %%
age=int(input('Enter youre age'))
print(f'I am {age} years old.')
# Out:
# Enter youre age 22
# I am 22 years old.

# %%
school=input('Enter youre school')
print(f'My school is {school}.')
# Out:
# Enter youre school Dharmaraja college kandy
# My school is Dharmaraja college kandy.

# %%
birth_year=2003
current_year=int(input('Enter current year'))
age=current_year-birth_year
print(f'I am {age}.')
# Out:
# Enter current year 2025
# I am 22.

# %%
Celsius=float(input('Enter Celsius'))
Fahrenheit=32+Celsius*9/5
print(f'Celsius {Celsius} is {Fahrenheit} in Fahrenheit.')
# Out:
# Enter Celsius 33
# Celsius 33.0 is 91.4 in Fahrenheit.

# %%
radius=float(input('Enter radius'))
area=2*3.14*radius**2
print(f'Area of the circle with the radius {radius} is {area}.')
# Out:
# Enter radius 5
# Area of the circle with the radius 5.0 is 157.0.

# %%
rate_per_hour=500
hours=int(input('Enter worked hours'))
total_pay=rate_per_hour*hours
print(f'Rs.{total_pay}')
# Out:
# Enter worked hours 22
# Rs.11000
